MB 3.9 MB/s eta 0:00:07
#    ------------------------- -------------- 39.1/62.3 MB 3.9 MB/s eta 0:00:07
#    ------------------------- -------------- 39.8/62.3 MB 3.9 MB/s eta 0:00:06
#    -------------------------- ------------- 40.6/62.3 MB 3.9 MB/s eta 0:00:06
#    -------------------------- ------------- 41.4/62.3 MB 3.9 MB/s eta 0:00:06
#    --------------------------- ------------ 42.2/62.3 MB 3.9 MB/s eta 0:00:06
#    --------------------------- ------------ 43.0/62.3 MB 3.9 MB/s eta 0:00:05
#    ---------------------------- ----------- 43.8/62.3 MB 3.9 MB/s eta 0:00:05
#    ---------------------------- ----------- 44.8/62.3 MB 3.9 MB/s eta 0:00:05
#    ----------------------------- ---------- 45.6/62.3 MB 3.9 MB/s eta 0:00:05
#    ----------------------------- ---------- 46.4/62.3 MB 3.9 MB/s eta 0:00:05
#    ------------------------------ --------- 47.2/62.3 MB 3.9 MB/s eta 0:00:04
#    ------------------------------ --------- 48.0/62.3 MB 3.9 MB/s eta 0:00:04
#    ------------------------------- -------- 49.0/62.3 MB 3.9 MB/s eta 0:00:04
#    ------------------------------- -------- 49.8/62.3 MB 3.9 MB/s eta 0:00:04
#    -------------------------------- ------- 50.6/62.3 MB 3.9 MB/s eta 0:00:04
#    -------------------------------- ------- 51.4/62.3 MB 3.9 MB/s eta 0:00:03
#    --------------------------------- ------ 52.2/62.3 MB 3.9 MB/s eta 0:00:03
#    ---------------------------------- ----- 53.0/62.3 MB 3.9 MB/s eta 0:00:03
#    ---------------------------------- ----- 53.7/62.3 MB 3.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 54.5/62.3 MB 3.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 55.3/62.3 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------ --- 56.4/62.3 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------ --- 57.1/62.3 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------- -- 57.9/62.3 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------- -- 58.7/62.3 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 59.5/62.3 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 60.3/62.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  61.1/62.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  61.9/62.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 62.3/62.3 MB 3.8 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.11-py3-none-any.whl (94 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Downloading orjson-3.10.15-cp312-cp312-win_amd64.whl (133 kB)
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/2.0 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.6 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.9.9-py3-none-win_amd64.whl (11.4 MB)
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.4 MB 5.0 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.4 MB 4.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.4 MB 4.2 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.4 MB 4.1 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.4 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.4 MB 4.0 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.4 MB 4.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.4 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.4 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.4/11.4 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.4 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.4 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 3.9 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.0-py3-none-any.whl (71 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading typer-0.15.2-py3-none-any.whl (45 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: pydub, tomlkit, shellingham, semantic-version, ruff, python-multipart, pydantic-core, orjson, markupsafe, groovy, ffmpy, annotated-types, aiofiles, uvicorn, starlette, pydantic, typer, safehttpx, fastapi, gradio
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# Successfully installed aiofiles-23.2.1 annotated-types-0.7.0 fastapi-0.115.11 ffmpy-0.5.0 gradio-5.20.0 groovy-0.1.2 markupsafe-2.1.5 orjson-3.10.15 pydantic-2.10.6 pydantic-core-2.27.2 pydub-0.25.1 python-multipart-0.0.20 ruff-0.9.9 safehttpx-0.1.6 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.46.0 tomlkit-0.13.2 typer-0.15.2 uvicorn-0.34.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\deeks\AppData\Local\Programs\Python\Python312\Lib\site-packages\~arkupsafe'.
#   You can safely remove it manually.

# %%
# !pip install -q pypdf
# !pip install -q python-dotenv

# %%
# !pip install -q transformers

# %%
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install  llama-cpp-python --no-cache-dir
# Out:
# 'CMAKE_ARGS' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install -q llama-index

# %%
# !pip -q install sentence-transformers

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (0.3.20)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.41)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\deeks\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)

# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))


from llama_index.core import Settings, VectorStoreIndex, SimpleDirectoryReader

from llama_index.core import ServiceContext

# %%
# !pip install llama_index
# Out:
# Requirement already satisfied: llama_index in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (0.12.22)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.4.6)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.1 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.4.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.22 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.12.22)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.6.8)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.3.25)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.4.6)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (1.65.4)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.22->llama_index) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (3.11.13)
# Requirement already satisfied: dataclasses-json in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (2025.2.0)
# Requirement already satisfied: httpx in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (3.4.2)
# Requirement already satisfied: numpy in c:\users\deeks\appdata\roaming\python\python312\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\deeks\appdata\roaming\python\python312\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\deeks\appdata\roaming\python\python312\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\deeks\appdata\roaming\python\python312\site-packages (from llama-index-core<0.13.0,>=0.12.22->llama_index) (1.17.2)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama_index) (0.1.13)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (4.13.3)
# Requirement already satisfied: pandas in c:\users\deeks\appdata\roaming\python\python312\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (5.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama_index) (0.6.2)
# Requirement already satisfied: click in c:\users\deeks\appdata\roaming\python\python312\site-packages (from nltk>3.8.1->llama_index) (8.1.8)
# Requirement already satisfied: joblib in c:\users\deeks\appdata\roaming\python\python312\site-packages (from nltk>3.8.1->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from nltk>3.8.1->llama_index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama_index) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama_index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama_index) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama_index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama_index) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama_index) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.22->llama_index) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (2.6)
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-cloud<0.2.0,>=0.1.13->llama-index-indices-managed-llama-cloud>=0.4.0->llama_index) (2025.1.31)
# Requirement already satisfied: anyio in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.22->llama_index) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.22->llama_index) (1.0.7)
# Requirement already satisfied: idna in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.22->llama_index) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.22->llama_index) (0.14.0)
# Requirement already satisfied: llama-cloud-services>=0.6.2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama_index) (0.6.4)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (0.8.2)
# Requirement already satisfied: sniffio in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.22->llama_index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.22->llama_index) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.22->llama_index) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.22->llama_index) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.22->llama_index) (3.1.1)
# Requirement already satisfied: colorama in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.22->llama_index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.22->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.22->llama_index) (3.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deeks\appdata\roaming\python\python312\site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\deeks\appdata\roaming\python\python312\site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (2025.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from llama-cloud-services>=0.6.2->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama_index) (1.0.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.22->llama_index) (24.2)
# Requirement already satisfied: six>=1.5 in c:\users\deeks\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (1.17.0)

# %%
import os

directory = "/content/Data/"
print("Exists:", os.path.exists(directory))
# Out:
# Exists: False

# %%
os.makedirs(directory, exist_ok=True)

# %%
directory = r"C:\Users\deeks\fashion-recommendation-sys\Chat-Bot"

# %%
# !mkdir Data
# !wget https://drive.google.com/uc?id=1b5JC1K5TRbYqESSHz-fgftuF1npiQvpA -O Data/Neozep.pdf

# !gdown 1gfBNlYCHVufQCPZZG_za7iXE36kOi-iq -O Data/fashion.pdf
# Out:
# A subdirectory or file Data already exists.
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1gfBNlYCHVufQCPZZG_za7iXE36kOi-iq
#
# but Gdown can't. Please check connections and permissions.

# %%
documents = SimpleDirectoryReader("/content/Data/").load_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 documents = SimpleDirectoryReader("/content/Data/").load_data()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\readers\file\base.py:278, in SimpleDirectoryReader.__init__(self, input_dir, input_files, exclude, exclude_hidden, exclude_empty, errors, recursive, encoding, filename_as_id, required_exts, file_extractor, num_files_limit, file_metadata, raise_on_error, fs)
#     276 elif input_dir:
#     277     if not self.fs.isdir(input_dir):
# --> 278         raise ValueError(f"Directory {input_dir} does not exist.")
#     279     self.input_dir = _Path(input_dir)
#     280     self.exclude = exclude
#
# ValueError: Directory /content/Data/ does not exist.

# %%
# %pip install llama-index-embeddings-huggingface
# %pip install llama-index-llms-llama-cpp

# %%
print(documents)

# %%
import torch
from llama_index.llms.llama_cpp import LlamaCPP
from llama_index.llms.llama_cpp.llama_utils import (
    messages_to_prompt,
    completion_to_prompt,
)
#from llama_index.llms import LlamaCPP
#from llama_index.llms.llama_utils import messages_to_prompt, completion_to_prompt
llm = LlamaCPP(
    # You can pass in the URL to a GGML model to download it automatically
    model_url='https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.1-GGUF/resolve/main/mistral-7b-instruct-v0.1.Q4_K_M.gguf',
    # optionally, you can set the path to a pre-downloaded model instead of model_url
    model_path=None,
    temperature=0.1,
    max_new_tokens=256,
    # llama2 has a context window of 4096 tokens, but we set it lower to allow for some wiggle room
    context_window=3900,
    # kwargs to pass to __call__()
    generate_kwargs={},
    # kwargs to pass to __init__()
    # set to at least 1 to use GPU
    model_kwargs={"n_gpu_layers": -1},
    # transform inputs into Llama2 format
    messages_to_prompt=messages_to_prompt,
    completion_to_prompt=completion_to_prompt,
    verbose=True,
)

# %%
import llama_index

dir(llama_index.core.indices.service_context.ServiceContext)

# %%
# %pip install llama-index-embeddings-langchain

# %%
from langchain.embeddings.huggingface import HuggingFaceEmbeddings

from llama_index.embeddings.langchain import LangchainEmbedding
#from llama_index.embeddings import LangchainEmbedding
#from llama_index import ServiceContext
from llama_index.core.indices.service_context import ServiceContext

embed_model = LangchainEmbedding(
  HuggingFaceEmbeddings(model_name="thenlper/gte-large")
)

# %%
service_context = ServiceContext.from_defaults(
    chunk_size=256,
    llm=llm,
    embed_model=embed_model
)

# %%
index = VectorStoreIndex.from_documents(documents, service_context=service_context)

# %%
query_engine = index.as_query_engine()

print(query_engine.query("what is the side effects of the neozep"))

# %%
import gradio as gr

def text_to_uppercase(text):
    return query_engine.query(text)

iface = gr.Interface(fn=text_to_uppercase, inputs="text", outputs="text")
iface.launch(debug=True)
